# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors
import seaborn as sns
from scipy import stats
import math
# %matplotlib inline
from sklearn import preprocessing

# %% [markdown]
# # Data: Superheroes

# %% [markdown]
# The following dataset displays superhero characteristics, the character name, and comic publisher. This information was taken from https://www.kaggle.com/claudiodavi/superhero-set/data. Manipulation of the dataset is for academic purposes.

# %%
df = pd.read_csv('C:\\Users\\cocob\\Downloads\\heroes_information.csv')

# %% [markdown]
# ## Basic Info about Dataset

# %%
df.head()
# Out:
#           name Gender Eye color   Race             Race.1 Hair color  Height  \
# 0        ABomb   Male    yellow  Human              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue  Alien      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue  Alien            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue  Alien      Cosmic Entity      Black    99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics        NaN      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics        NaN       bad   441.0
# 4      Marvel Comics        NaN       bad    99.0

# %%
df.shape
# Out:
# (734, 11)

# %%
df.dtypes
# Out:
# name           object
# Gender         object
# Eye color      object
# Race           object
# Race.1         object
# Hair color     object
# Height        float64
# Publisher      object
# Skin color     object
# Alignment      object
# Weight        float64
# dtype: object

# %%
df.describe()
# Out:
#            Height      Weight
# count  734.000000  732.000000
# mean   160.790872  107.961749
# std     63.845126   85.843309
# min     15.200000    2.000000
# 25%     99.000000   74.000000
# 50%    175.000000   99.000000
# 75%    185.000000   99.000000
# max    975.000000  900.000000

# %%
pd.crosstab(df['Alignment'], df['Gender'],margins=True)
# Out:
# Gender     Female  Male  All
# Alignment
# bad            35   165  200
# good          161   316  477
# neutral         4    24   28
# All           200   505  705

# %% [markdown]
# ## Data Transformation

# %%
df.dropna()
# Out:
#                    name  Gender                Eye color            Race  \
# 1            Abe Sapien    Male                     blue           Alien
# 2              Abin Sur    Male                     blue           Alien
# 34           Apocalypse    Male                      red          Mutant
# 39            Archangel    Male                     blue          Mutant
# 41               Ardina  Female                    white           Alien
# 56               Azazel    Male                   yellow        Woodland
# 74                Beast    Male                     blue          Mutant
# 75            Beast Boy    Male                    green           Human
# 92              Bizarro    Male                    black   Machine/Droid
# 108            Blackout    Male                      red           Demon
# 114               Blink  Female                    green          Mutant
# 135            Brainiac    Male                    green   Machine/Droid
# 149        Captain Atom    Male                     blue           Human
# 166             Century    Male                    white           Alien
# 185             Copycat  Female                      red          Mutant
# 203            Darkseid    Male                      red             God
# 226              Domino  Female                     blue           Human
# 227           Donatello    Male                    green          Mutant
# 232        Dr Manhattan    Male                    white  Human / Cosmic
# 233  Drax the Destroyer    Male                      red           Human
# 245             Etrigan    Male                      red           Demon
# 247            Evilhawk    Male                      red           Alien
# 248              Exodus    Male                     blue          Mutant
# 255       Fin Fang Foom    Male                      red           Alien
# 274              Gamora  Female                   yellow           Alien
# 284           Gladiator    Male                     blue           Alien
# 331                Hulk    Male                    green           Human
# 369               Joker    Male                    green           Human
# 377                K2SO    Male                    white   Machine/Droid
# 386         Killer Croc    Male                      red           Human
# 387        Killer Frost  Female                     blue           Human
# 388             Kilowog    Male                      red           Alien
# 392                Klaw    Male                      red           Human
# 404            Leonardo    Male                     blue          Mutant
# 413                Lobo    Male                      red           Alien
# 431              Mantis  Female                    green           Human
# 432   Martian Manhunter    Male                      red           Alien
# 480            Mystique  Female  yellow (without irises)          Mutant
# 487              Nebula  Female                     blue        Woodland
# 497                Nova  Female                    white           Human
# 523          Poison Ivy  Female                    green           Human
# 533          Purple Man    Male                   purple           Human
# 549            Red Hulk    Male                   yellow           Human
# 587         Shadow Lass  Female                    black        Woodland
# 600       Silver Surfer    Male                    white           Alien
# 603            Sinestro    Male                    black           Alien
# 615             Spectre    Male                    white             God
# 634            Starfire  Female                    green        Woodland
# 639         Steppenwolf    Male                      red             God
# 647         Swamp Thing    Male                      red             God
# 648               Swarm    Male                   yellow          Mutant
# 657              Thanos    Male                      red             God
# 668         Tiger Shark    Male                     grey           Human
# 672                Toad    Male                    black          Mutant
# 677              Trigon    Male                   yellow             God
# 679              Triton    Male                    green           Demon
# 699              Vision    Male                     gold   Machine/Droid
# 730                Ymir    Male                    white           Demon
# 731                Yoda    Male                    brown           Alien
#
#                 Race.1    Hair color  Height          Publisher Skin color  \
# 1        Icthyo Sapien       No Hair   191.0  Dark Horse Comics       blue
# 2              Ungaran       No Hair   185.0          DC Comics        red
# 34              Mutant         Black   213.0      Marvel Comics       grey
# 39              Mutant         Blond   183.0      Marvel Comics       blue
# 41               Alien        Orange   193.0      Marvel Comics       gold
# 56            Neyaphem         Black   183.0      Marvel Comics        red
# 74              Mutant          Blue   180.0      Marvel Comics       blue
# 75               Human         Green   173.0          DC Comics      green
# 92             Bizarro         Black   191.0          DC Comics      white
# 108              Demon         White   191.0      Marvel Comics      white
# 114             Mutant       Magenta   165.0      Marvel Comics       pink
# 135            Android       No Hair   198.0          DC Comics      green
# 149  Human / Radiation        Silver   193.0          DC Comics     silver
# 166              Alien         White   201.0      Marvel Comics       grey
# 185             Mutant         White   183.0      Marvel Comics       blue
# 203            New God       No Hair   267.0          DC Comics       grey
# 226              Human         Black   173.0      Marvel Comics      white
# 227             Mutant       No Hair    99.0     IDW Publishing      green
# 232     Human / Cosmic       No Hair    99.0          DC Comics       blue
# 233    Human / Altered       No Hair   193.0      Marvel Comics      green
# 388      good   324.0
# 392       bad    97.0
# 404      good    99.0
# 413   neutral   288.0
# 431      good    52.0
# 432      good   135.0
# 480       bad    54.0
# 487       bad    83.0
# 497      good    59.0
# 523       bad    50.0
# 533       bad    74.0
# 549   neutral   630.0
# 587      good    54.0
# 600      good   101.0
# 603   neutral    92.0
# 615      good    99.0
# 634      good    71.0
# 639       bad    91.0
# 647       bad    99.0
# 648       bad    47.0
# 657       bad   443.0
# 668       bad   203.0
# 672   neutral    76.0
# 677       bad    99.0
# 679      good    86.0
# 699      good   135.0
# 730      good    99.0
# 731      good    17.0

# %%
df['Male'] = np.where((df['Gender'].isin(['Male'])), 1, 0)

# %%
df['Female'] = np.where((df['Gender'].isin(['Female'])), 1, 0)

# %%
df['Good'] = np.where((df['Alignment'].isin(['good'])), 1, 0)

# %%
df['Bad'] = np.where((df['Alignment'].isin(['bad'])), 1, 0)

# %%
df['Hair'] = np.where((df['Hair color'].isin(['No Hair'])), 'No Hair', 'Hair')

# %%
df['Hair2'] = np.where((df['Hair color'].isin(['No Hair'])), 0, 1)

# %%
df.head()
# Out:
#           name Gender Eye color   Race             Race.1 Hair color  Height  \
# 0        ABomb   Male    yellow  Human              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue  Alien      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue  Alien            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue  Alien      Cosmic Entity      Black    99.0
#
#            Publisher Skin color Alignment  Weight  Male  Female  Good  Bad  \
# 0      Marvel Comics        NaN      good   441.0     1       0     1    0
# 1  Dark Horse Comics       blue      good    65.0     1       0     1    0
# 2          DC Comics        red      good    90.0     1       0     1    0
# 3      Marvel Comics        NaN       bad   441.0     1       0     0    1
# 4      Marvel Comics        NaN       bad    99.0     1       0     0    1
#
#       Hair  Hair2
# 0  No Hair      0
# 1  No Hair      0
# 2  No Hair      0
# 3  No Hair      0
# 4     Hair      1

# %% [markdown]
# ## Exploratory Analysis

# %%
sns.countplot(x='Alignment', data=df);

# %% [markdown]
# The graph above demonstrates how many superheros are bad, good, or neutral. For the purpose of this project, main focus will be directed toward good and bad alignment. The analysis below will determine which gender, skin color, hair, and race generate what alignment.

# %% [markdown]
# ### Gender and Alignment Correlation

# %%
df3 = pd.crosstab(df['Alignment'], df['Race'],margins=True)

# %%
stats.ttest_ind(df['Bad'], df['Male'])
# Out:
# Ttest_indResult(statistic=-17.01899303313765, pvalue=2.0534843544272114e-59)

# %%
stats.ttest_ind(df['Good'], df['Male'])
# Out:
# Ttest_indResult(statistic=-0.5040477086887254, pvalue=0.6143035910718535)

# %%
stats.ttest_ind(df['Bad'], df['Female'])
# Out:
# Ttest_indResult(statistic=0.40788221587086176, pvalue=0.6834197088324643)

# %%
stats.ttest_ind(df['Good'], df['Female'])
# Out:
# Ttest_indResult(statistic=16.900485622867876, pvalue=1.1084252540076607e-58)

# %% [markdown]
# Given the p-values, there is a correlation between gender and alignment. Males are more likely to be bad in comparison to females who have a stronger correlation for being good. The graph below visualizes this point.

# %%
sns.set(style='whitegrid')
sns.factorplot(x='Gender', y='Good', data=df, size=5, kind='bar', palette='BuPu')
plt.show()

# %% [markdown]
# ### Alignment by Physical Features

# %% [markdown]
# #### Hero Alignment Given Skin Color

# %%
pd.crosstab(df['Alignment'], df['Skin color'],margins=True)
# Out:
# Skin color  black  blue  bluewhite  gold  gray  green  grey  orange  \
# Alignment
# bad             1     3          0     0     0      6     4       0
# good            0     5          0     2     1     14     1       1
# neutral         0     1          1     1     0      1     0       0
# All             1     9          1     3     1     21     5       1
#
# Skin color  orange / white  pink  purple  red  red / black  silver  white  \
# Alignment
# bad                      0     0       2    4            1       3      3
# good                     1     2       0    3            0       2      3
# neutral                  0     0       1    2            0       0      1
# All                      1     2       3    9            1       5      7
#
# Skin color  yellow  All
# Alignment
# bad              1   28
# good             0   35
# neutral          1    9
# All              2   72

# %%
sns.set(font_scale=2)
plt.subplots(figsize=(25,10))
sns.swarmplot(x='Skin color', y='Good', data=df, size=15, palette='Spectral')
plt.show()

# %% [markdown]
# Shown above is the superhero alignment by skin color. Most notable colors were blue, red, grey, and green since majority of superheroes are these colors. Grey superheroes illustrate 4/5 chance in being bad. While the black superhero is likely to align as bad, the n value in only one.
#
# Upon inspection, grey spectrum skin colors were more likely to display bad alignment in comparison to the remaining colors. This notion demonstrates that color vibrancy may be an indicator of character alignment. Green superheroes clearly promote this notion as they are mostly likely to be good.

# %% [markdown]
# #### Alignment based on Hair

# %%
df['Hair2'] = np.where((df['Hair color'].isin(['No Hair'])), 0, 1)
stats.ttest_ind(df['Bad'], df['Hair2'])
# Out:
# Ttest_indResult(statistic=-30.736655498666014, pvalue=1.518703872000688e-160)

# %%
stats.ttest_ind(df['Good'], df['Hair2'])
# Out:
# Ttest_indResult(statistic=-10.783684960480832, pvalue=3.8190308232290055e-26)

# %% [markdown]
# sns.set(style='whitegrid')
# sns.factorplot(x='Hair', y='Good', data=df, kind='point', palette='rainbow', size=5)
# plt.show()

# %% [markdown]
# Based on the info provided above, superhereos with hair are more likely to align good. Contrastly, superhereos without hair are more likely to align bad.

# %%
sns.set(font_scale=2)
sns.factorplot(x='Race', y='Good', data=df, kind='point', palette='rainbow', size=15)
plt.show()

# %% [markdown]
# Most Races vary staying within between bad and almost good. Woodland, Demon, and god consist of a wide range. Humans and Mutants trend closer to good. While Human/Cosmic is aligns good, there is only a n value of one.
