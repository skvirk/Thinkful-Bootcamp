# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\\Users\\cocob\\Downloads\\UNdata_Export_20180329_050756736.csv')

# %%
data.head(11)
# Out:
#    Country or Area  Year Comm. Code        Commodity    Flow  Trade (USD)  \
# 0      Afghanistan  2016      TOTAL  ALL COMMODITIES  Import   6534140413
# 1      Afghanistan  2016      TOTAL  ALL COMMODITIES  Export    596455337
# 2      Afghanistan  2015      TOTAL  ALL COMMODITIES  Import   7722865049
# 3      Afghanistan  2015      TOTAL  ALL COMMODITIES  Export    571404967
# 4      Afghanistan  2014      TOTAL  ALL COMMODITIES  Import   7697178170
# 5      Afghanistan  2014      TOTAL  ALL COMMODITIES  Export    570534007
# 6      Afghanistan  2013      TOTAL  ALL COMMODITIES  Import   8554413749
# 7      Afghanistan  2013      TOTAL  ALL COMMODITIES  Export    514972983
# 8      Afghanistan  2012      TOTAL  ALL COMMODITIES  Import   6204984101
# 9      Afghanistan  2012      TOTAL  ALL COMMODITIES  Export    428902710
# 10     Afghanistan  2011      TOTAL  ALL COMMODITIES  Import   6390310947
#
#     Weight (kg) Quantity Name  Quantity
# ...

# %%
data.plot('Country or Area', 'Trade (USD)')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
data['Trade (USD)'].describe()
# Out:
# count    9.185000e+03
# mean     6.364002e+10
# std      2.007189e+11
# min      2.000000e+00
# 25%      4.370894e+08
# 50%      3.828449e+09
# 75%      3.250349e+10
# max      2.443311e+12
# Name: Trade (USD), dtype: float64

# %%
data.groupby(['Country or Area', 'Trade (USD)']).sum()
# Out:
#                              Year  Weight (kg)  Quantity
# Country or Area Trade (USD)
# Afghanistan     375850935    2011          0.0       0.0
#                 388483635    2010          0.0       0.0
#                 403441006    2009          0.0       0.0
#                 428902710    2012          0.0       0.0
#                 514972983    2013          0.0       0.0
#                 540065594    2008          0.0       0.0
#                 570534007    2014          0.0       0.0
#                 571404967    2015          0.0       0.0
#                 596455337    2016          0.0       0.0
#                 3019860129   2008          0.0       0.0
#                 3336434781   2009          0.0       0.0
#                 5154249867   2010          0.0       0.0
#                 6204984101   2012          0.0       0.0
#                 6390310947   2011          0.0       0.0
#                 6534140413   2016          0.0       0.0
# ...

# %%
data1= data[['Country or Area', 'Trade (USD)']]

# %%
data2= data1.groupby(['Country or Area'])['Trade (USD)'].sum().reset_index()

# %%
data2.plot()
plt.show()

# %%
data2.plot(kind= 'bar', figsize=(20,5))
plt.show()

# %%
data3= data2.sort_values(by='Trade (USD)', ascending=False)

# %%
data3
# Out:
#             Country or Area     Trade (USD)
# 195                     USA  66042154242354
# 57                    EU-28  53531258535647
# 40                    China  43805281069768
# 76                  Germany  43032133224839
# 98                    Japan  28523607658364
# 41     China, Hong Kong SAR  22225222266813
# 199          United Kingdom  20473651515488
# 70                   France  20319340380703
# 96                    Italy  16772507054147
# 35                   Canada  16338264562858
# 132             Netherlands  15900638890807
# 151           Rep. of Korea  14677005652531
# 18                  Belgium  12549250025744
# 168               Singapore  11159226734142
# 122                  Mexico  10979147667267
# 174                   Spain  10875708582583
# 154      Russian Federation   8854742352156
# 140         Other Asia, nes   8187175682000
# 90                    India   8091629099452
# 181             Switzerland   8015098542685
# ...

# %%
data3.index=data3['Country or Area']
data3[0:49].plot(kind='bar', figsize=(20,5))
plt.show()
